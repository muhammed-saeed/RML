# %%
from src.dataloaders import imagenet_c_dataloader, imagenet_dataloader
import matplotlib.pyplot as plt
import numpy as np

# %%
loader_c = imagenet_c_dataloader()
len(loader_c)*64
# Out:
# 50048

# %%
for batch in loader_c:
    images, labels = batch
    break

# %%
img = images[0].permute(1, 2, 0).numpy()
img = img - np.min(img)
img /= np.max(img)
plt.imshow(img)

# %%
loader = imagenet_dataloader()
len(loader)*64
# Out:
# 50048

# %%
for batch in loader:
    images, labels = batch
    break

# %%
img = images[0].permute(1, 2, 0).numpy()
img -= np.min(img)
img /= np.max(img)
plt.imshow(img)
